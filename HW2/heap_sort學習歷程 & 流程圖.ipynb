# %% [markdown]
# 參考資料1：https://www.youtube.com/watch?v=GnKHVXv_rlQ
# 參考資料2:https://gist.github.com/showell/1418901
# 問題諮詢者：厲彥伯

# %% [markdown]
# 初步想法：

# %% [markdown]
# 1.將每個數值賦予index
# for i in range(i,len(list)-1)
# parent = list i
# left = list 2* i+ 1
# right = list 2* i+ 2

# %% [markdown]
# 2.檢查list的長度：是否有left-children,right-children
# if len(list) <= 1:
#     return list

# %% [markdown]
# 3.＊從index 0,1,2開始＊
# if left > parent,swap
# if arr[1] > arr[0]:
#    arr[1], arr[0] = arr[0], arr[1]
#
# if right > parent,swap
# if arr[2] > arr[0]:
#    arr[2], arr[0] = arr[0], arr[2]

# %% [markdown]
# 用一個“largest”存取目前比較的過程
# if left < length and arr[largest] < arr[left]:
#     largest = left
# if right < length and arr[largest] < arr[right]:
#     largest = right

# %% [markdown]
# 4.將最大值放入arr[index0]
#  arr[largest], arr[i] = arr[i], arr[largest]

# %% [markdown]
# 5.當最大值＝index0時，取出放進新的arr，並將index=len(arr)-1放入index = 0
# arr2 = []
# arr2.append(arr[index = 0])
# arr[index=0] = arr[index(len(list)-1)]

# %% [markdown]
# 我假設最大的數字在"i"
# 接著跟left ＆ right比較，並將最大的數存在largest

# %%
class Solution():
     def maxheapify(self,arr,length,i):
        left = 2 * i + 1
        right = 2 * i + 2
        largest = i
        if arr[largest] < arr[left]:
            largest = left
        if arr[largest] < arr[right]:
            largest = right
            
        if largest != i:
            arr[largest], arr[i] = arr[i], arr[largest]
            Solution().maxheapify(arr, length, largest)

# %% [markdown]
# 在比較之後會用largest存取最大值，可是此時位置還沒交換。
# 把largest放到arr[i]，方便最後取值

# %% [markdown]
# 假設最大的數不在"i"，left跟largest交換位置後會產生問題
# ➡️left 的子結點有可能大於left，例如index = 1需要兩次的比較。
# 此時我得出index= ?就需要？- 1次的檢查
# 然而？- 1次又要怎麼用程式表達呢
# ➡️ int((length / 2) - 1)

# %%
 def heapbuild(self, arr):
        lenght = len(arr)
        leftt = int((length / 2) -1)             
        while leftt >= 0:                 
            Solution().maxheapify(arr, length, leftt)
            leftt -= 1

# %% [markdown]
# leftt = 需要重複檢查的node
# 一直減1向上比較

# %% [markdown]
# 接下來我想到的是，將整理好的arr取出largest，再由最小的index取代index = 0
# 終止的條件是，當arr的長度只剩下1個，不需要再比較了

# %%
def heapsort(self, arr):
        length = len(arr)
        Solution().heapbuild(arr)
    
        while length < 2:
            arr[0], arr[length - 1] = arr[length - 1], arr[0]
            length -= 1
            Solution().maxheapify(arr, length, 0)
        return arr

# %%
把所有def合併執行看看

# %%
class Solution():
     def maxheapify(self,arr,length,i):
        left = 2 * i + 1
        right = 2 * i + 2
        largest = i
        if arr[largest] < arr[left]:
            largest = left
        if  arr[largest] < arr[right]:
            largest = right
            
        if largest != i:
            arr[largest], arr[i] = arr[i], arr[largest]
            Solution().maxheapify(arr, length, largest)
    def heapbuild(self, arr):
        lenght = len(arr)
        leftt = int((length / 2) -1)             
        while leftt >= 0:                 
            Solution().maxheapify(arr, length, leftt)
            leftt -= 1 
    def heapsort(self, arr):
        length = len(arr)
        Solution().heapbuild(arr)
    
        while length < 2:
            arr[0], arr[length - 1] = arr[length - 1], arr[0]
            length -= 1
            Solution().maxheapify(arr, length, 0)
        return arr
# Out:
#   File "<tokenize>", line 14
#     def heapbuild(self, arr):
#     ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# 查詢"unindent does not match any outer indentation level"，發現是縮排錯誤
# https://www.itread01.com/content/1541745426.html

# %% [markdown]
# 重新整理排序後

# %%
class Solution():
    def maxheapify(self,arr,length,i):
        left = 2 * i + 1
        right = 2 * i + 2
        largest = i
        if arr[largest] < arr[left]:
            largest = left
        if  arr[largest] < arr[right]:
            largest = right
            
        if largest != i:
            arr[largest], arr[i] = arr[i], arr[largest]
            Solution().maxheapify(arr, length, largest)
    def heapbuild(self, arr):
        lenght = len(arr)
        leftt = int((length / 2) -1)             
        while leftt >= 0:                 
            Solution().maxheapify(arr, length, leftt)
            leftt -= 1 
    def heapsort(self, arr):
        length = len(arr)
        Solution().heapbuild(arr)
    
        while length < 2:
            arr[0], arr[length - 1] = arr[length - 1], arr[0]
            length -= 1
            Solution().maxheapify(arr, length, 0)
        return arr

# %%
list = [3,6,9,11,43,2,1]
Solution().heapsort(list)
list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-477e4a849135> in <module>
#       1 list = [3,6,9,11,43,2,1]
# ----> 2 Solution().heapsort(list)
#       3 list
#
# <ipython-input-23-e198250c9920> in heapsort(self, arr)
#      20     def heapsort(self, arr):
#      21         length = len(arr)
# ---> 22         Solution().heapbuild(arr)
#      23
#      24         while length < 2:
#
# <ipython-input-23-e198250c9920> in heapbuild(self, arr)
#      14     def heapbuild(self, arr):
#      15         lenght = len(arr)
# ---> 16         leftt = int((length / 2) -1)
#      17         while leftt >= 0:
#      18             Solution().maxheapify(arr, length, leftt)
#
# NameError: name 'length' is not defined

# %%
class Solution():
    def maxheapify(self,arr,length,i):
        left = 2 * i + 1
        right = 2 * i + 2
        largest = i
        if arr[largest] < arr[left]:
            largest = left
        if  arr[largest] < arr[right]:
            largest = right
            
        if largest != i:
            arr[largest], arr[i] = arr[i], arr[largest]
            Solution().maxheapify(arr, length, largest)
    def heapbuild(self, arr,length):
        lenght = len(arr)
        leftt = int((length / 2) -1)             
        while leftt >= 0:                 
            Solution().maxheapify(arr, length, leftt)
            leftt -= 1 
    def heapsort(self, arr):
        length = len(arr)
        Solution().heapbuild(arr)
    
        while length < 2:
            arr[0], arr[length - 1] = arr[length - 1], arr[0]
            length -= 1
            Solution().maxheapify(arr, length, 0)
        return arr

# %%
list = [3,6,9,11,43,2,1]
Solution().heapsort(list)
list
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-477e4a849135> in <module>
#       1 list = [3,6,9,11,43,2,1]
# ----> 2 Solution().heapsort(list)
#       3 list
#
# <ipython-input-25-e4c1aeb0f8a9> in heapsort(self, arr)
#      20     def heapsort(self, arr):
#      21         length = len(arr)
# ---> 22         Solution().heapbuild(arr)
#      23
#      24         while length < 2:
#
# TypeError: heapbuild() missing 1 required positional argument: 'length'

# %%
class Solution():
    def maxheapify(self,arr,length,i):
        left = 2 * i + 1
        right = 2 * i + 2
        largest = i
        if arr[largest] < arr[left]:
            largest = left
        if  arr[largest] < arr[right]:
            largest = right
            
        if largest != i:
            arr[largest], arr[i] = arr[i], arr[largest]
            Solution().maxheapify(arr, length, largest)
    def heapbuild(self, arr,length):
        lenght = len(arr)
        leftt = int((length / 2) -1)             
        while leftt >= 0:                 
            Solution().maxheapify(arr, length, leftt)
            leftt -= 1 
    def heapsort(self, arr):
        length = len(arr)
        Solution().heapbuild(arr,length)
    
        while length < 2:
            arr[0], arr[length - 1] = arr[length - 1], arr[0]
            length -= 1
            Solution().maxheapify(arr, length, 0)
        return arr

# %%
list = [3,6,9,11,43,2,1]
Solution().heapsort(list)
list
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-28-477e4a849135> in <module>
#       1 list = [3,6,9,11,43,2,1]
# ----> 2 Solution().heapsort(list)
#       3 list
#
# <ipython-input-27-f9a9a4ed36f3> in heapsort(self, arr)
#      20     def heapsort(self, arr):
#      21         length = len(arr)
# ---> 22         Solution().heapbuild(arr,length)
#      23
#      24         while length < 2:
#
# <ipython-input-27-f9a9a4ed36f3> in heapbuild(self, arr, length)
#      16         leftt = int((length / 2) -1)
#      17         while leftt >= 0:
# ---> 18             Solution().maxheapify(arr, length, leftt)
#      19             leftt -= 1
#      20     def heapsort(self, arr):
#
# <ipython-input-27-f9a9a4ed36f3> in maxheapify(self, arr, length, i)
#      11         if largest != i:
#      12             arr[largest], arr[i] = arr[i], arr[largest]
# ---> 13             Solution().maxheapify(arr, length, largest)
#      14     def heapbuild(self, arr,length):
#      15         lenght = len(arr)
#
# <ipython-input-27-f9a9a4ed36f3> in maxheapify(self, arr, length, i)
#       4         right = 2 * i + 2
#       5         largest = i
# ----> 6         if arr[largest] < arr[left]:
#       7             largest = left
#       8         if  arr[largest] < arr[right]:
#
# IndexError: list index out of range

# %% [markdown]
# 我發現這次的error不再是missing requirement，是list 超出範圍
# ➡️所以我覺得應該是第6行的部分，條件不足
# 我查了資料發現：應該要先檢查left & right是否存在
# 確定存在後才能比大小
# 所以我把第6、8行多加了兩個條件
# 參考文獻：https://www.geeksforgeeks.org/python-program-for-heap-sort/

# %%
class Solution():
     def maxheapify(self,arr,length,i):
        left = 2 * i + 1
        right = 2 * i + 2
        largest = i
        if left < length and arr[largest] < arr[left]:
            largest = left
        if right < length and arr[largest] < arr[right]:
            largest = right
            
        if largest != i:
            arr[largest], arr[i] = arr[i], arr[largest]
            Solution().maxheapify(arr, length, largest)

# %%
class Solution():
    def maxheapify(self,arr,length,i):
        left = 2 * i + 1
        right = 2 * i + 2
        largest = i
        if left < length and arr[largest] < arr[left]:
            largest = left
        if right < length and arr[largest] < arr[right]:
            largest = right
            
        if largest != i:
            arr[largest], arr[i] = arr[i], arr[largest]
            Solution().maxheapify(arr, length, largest)
    def heapbuild(self, arr,length):
        lenght = len(arr)
        leftt = int((length / 2) -1)             
        while leftt >= 0:                 
            Solution().maxheapify(arr, length, leftt)
            leftt -= 1 
    def heapsort(self, arr):
        length = len(arr)
        Solution().heapbuild(arr,length)
    
        while length < 2:
            arr[0], arr[length - 1] = arr[length - 1], arr[0]
            length -= 1
            Solution().maxheapify(arr, length, 0)
        return arr

# %%
list = [3,6,9,11,43,2,1]
Solution().heapsort(list)
list
# Out:
# [43, 11, 9, 3, 6, 2, 1]

# %% [markdown]
# 這是heap_sort流程圖

# %%
from IPython.display import Image
Image(filename="/Users/maggie/Downloads/heap_sort(1).png")

# %%
from IPython.display import Image
Image(filename="/Users/maggie/Downloads/heap_sort(2).png")

# %%
from IPython.display import Image
Image(filename="/Users/maggie/Downloads/heap_sort(3).png")

# %%
from IPython.display import Image
Image(filename="/Users/maggie/Downloads/heap_sort(4).png")
